# %%
import csv


fh = open("C:\\Users\\Helen\\OneDrive\\Desktop\\visualandSensing.csv", "w")
writer = csv.writer(fh)

writer.writerow(["date", "Text"])

# ... code ...

writer.writerow( [key, repA] )

# ... code ...

fh.close()

# %%
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
columns = ["date", "mean_temp"]
df = pd.read_csv("C:\\Users\\Helen\\OneDrive\\Desktop\\visualandSensing\\london_weather.csv", usecols=columns)
print("Contents in csv file:\n", df)
plt.plot(df.date, df.mean_temp)
plt.show()
# Out:
# Contents in csv file:
#             date  mean_temp
# 0      19790101       -4.1
# 1      19790102       -2.6
# 2      19790103       -2.8
# 3      19790104       -2.6
# 4      19790105       -0.8
# ...         ...        ...
# 15336  20201227        7.5
# 15337  20201228        1.1
# 15338  20201229        2.6
# 15339  20201230        2.7
# 15340  20201231       -0.8
#
# [15341 rows x 2 columns]
